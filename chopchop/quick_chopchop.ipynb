# %%
cmd = "-J -BED -GenBank -G hg19 -filterGCmin 10 -filterGCmax 90 -t WHOLE -n N -R 4 " + \
      "-3 PRODUCT_SIZE_MIN=150,PRODUCT_SIZE_MAX=290,PRIMER_MIN_SIZE=18,PRIMER_MAX_SIZE=25,PRIMER_OPT_SIZE=22,PRIMER_MIN_TM=57,PRIMER_MAX_TM=63,PRIMER_OPT_TM=60 " + \
      "-P -A 290 -DF 300 -a 20 -T 1 -g 20 -scoringMethod DOENCH_2016 -f NN -v 3 -repairPredictions mESC -M NGG -BB AGGCTAGTCCGT"

# %%
cmd_user = " ".join( ["--targets chr11:5292000-5293000 -o ./xu/whole",cmd] )
# !/cluster2/huanglab/liquan/miniconda3/envs/cp27/bin/python ./chopchop.py $cmd_user > ./xu/whole/results_hg19_ag.tsv
# !rm -r ./xu/whole/*.offtargets
# !rm -r ./xu/whole/*.json
# !rm -r ./xu/whole/*repProfile.csv
# !rm -r ./xu/whole/*primer3Input
# !rm -r ./xu/whole/*.gb
# Out:
# [0.66353691 0.33795623 0.41678947 0.56299276 0.45582709 0.52414255
#  0.42788669 0.52846916 0.37205716 0.43371889 0.33101796 0.62267607
#  0.41409781 0.51142102 0.4725337  0.35079677 0.685779   0.71286213
#  0.41071629 0.46319321 0.39918631 0.54957974 0.46235426 0.3925458
#  0.61414108 0.49784258 0.20780192 0.38919452 0.63102591 0.32666114
#  0.64705294 0.67093481 0.33213789 0.37704324 0.4419018  0.58635129
#  0.45983657 0.62509852 0.48152693 0.33793254 0.43366443 0.54522573
#  0.69707283 0.58792159 0.43090104 0.2649714  0.50055771 0.57525974
#  0.42608164 0.41178148 0.45848469 0.65669987 0.5301968  0.48943691
#  0.4046494  0.41662503 0.46727333 0.51086781 0.43644069 0.48430193
#  0.58841001 0.60061813 0.5760483  0.48275983 0.5031523  0.69096163
#  0.61752771 0.59752768 0.39055617 0.35226436 0.4976929  0.45614768
#  0.43639154 0.48117865 0.49047002 0.6554424  0.61986427 0.55249542
#  0.43563847 0.18982988 0.62673887 0.55246573 0.33124874 0.54486094
# ...

# %%
# !/cluster2/huanglab/liquan/miniconda3/envs/cp27/bin/python \
./chopchop.py -G hg19 -t WHOLE -o ./xu/whole -BED -Target  chr11:5292000-5316000
